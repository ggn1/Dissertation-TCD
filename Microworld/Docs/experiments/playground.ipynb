# %% [markdown]
# # Playground

# %% [markdown]
# This file analyzes data from simulation runs.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
land_size = {"rows": 6, "columns": 6}
time_max = 300

# %%
df = pd.read_csv("data/too_little_co2.csv")
df
# Out:
#      time         c_air        c_soil         c_veg  co2_ppm p00_type  \
# 0       0  2.279989e+18  0.000000e+00  1.119659e+13  1638.22        C
# 1       1  2.279910e+18  1.086069e+11  8.957270e+13  1638.16        C
# 2       2  2.279697e+18  9.742038e+11  3.023079e+14  1638.01        C
# 3       3  2.279280e+18  3.877364e+12  7.165816e+14  1637.71        C
# 4       4  2.278590e+18  1.071188e+13  1.399573e+15  1637.21        C
# ..    ...           ...           ...           ...      ...      ...
# 296   296  8.450405e+17  6.329582e+17  8.020013e+17   607.18        C
# 297   297  9.051810e+17  6.476410e+17  7.271780e+17   650.39        C
# 298   298  9.650704e+17  6.619648e+17  6.529648e+17   693.42        C
# 299   299  9.954233e+17  6.604173e+17  6.241594e+17   715.23        C
# 300   300  1.008176e+18  6.497140e+17  6.221097e+17   724.39        C
#
#      p00_stage  p00_stress  p00_stress_age  p00_stress_env  ...  \
# 0            1           0               0          0.0005  ...
# 1            1           0               0          0.0005  ...
# 2            1           0               0          0.0005  ...
# 3            1           0               0          0.0005  ...
# 4            2           0               0          0.0005  ...
# ..         ...         ...             ...             ...  ...
# 296          2           0               0          0.0001  ...
# 297          2           0               0          0.0001  ...
# 298          2           0               0          0.0001  ...
# 299          2           0               0          0.0001  ...
# 300          2           0               0          0.0000  ...
#
#      p42_c_absorbed p43_c_absorbed  p44_c_absorbed  p45_c_absorbed  \
# 0      3.110163e+11   3.110163e+11    3.110163e+11    3.110163e+11
# 1      2.177114e+12   2.177114e+12    2.177114e+12    2.177114e+12
# 2      5.909310e+12   5.909310e+12    5.909310e+12    5.909310e+12
# 3      1.150760e+13   1.150760e+13    1.150760e+13    1.150760e+13
# 4      1.897199e+13   1.897199e+13    1.897199e+13    1.897199e+13
# ..              ...            ...             ...             ...
# 296    1.244065e+10   1.244065e+10    1.458666e+14    2.430000e+01
# 297    1.244065e+10   1.244065e+10    1.701259e+14    2.430000e+01
# 298    1.244065e+10   1.244065e+10    1.962513e+14    2.430000e+01
# 299    1.244065e+10   1.244065e+10    2.242428e+14    0.000000e+00
# 300    1.244065e+10   1.244065e+10    2.541003e+14    0.000000e+00
#
#      p50_c_absorbed  p51_c_absorbed  p52_c_absorbed p53_c_absorbed  \
# 0      3.110163e+11    3.110163e+11    3.110163e+11   3.110163e+11
# 1      2.177114e+12    2.177114e+12    2.177114e+12   2.177114e+12
# 2      5.909310e+12    5.909310e+12    5.909310e+12   5.909310e+12
# 3      1.150760e+13    1.150760e+13    1.150760e+13   1.150760e+13
# 4      1.897199e+13    1.897199e+13    1.897199e+13   1.897199e+13
# ..              ...             ...             ...            ...
# 296    8.680465e+14    3.949907e+13    3.949907e+13   1.897199e+13
# 297    8.680465e+14    5.256176e+13    5.256176e+13   2.830248e+13
# 298    8.680465e+14    6.749054e+13    6.749054e+13   3.949907e+13
# 299    0.000000e+00    6.749054e+13    6.749054e+13   3.949907e+13
# 300    0.000000e+00    8.428542e+13    8.428542e+13   5.256176e+13
#
#      p54_c_absorbed  p55_c_absorbed
# 0      3.110163e+11    3.110163e+11
# 1      2.177114e+12    2.177114e+12
# 2      5.909310e+12    5.909310e+12
# 3      1.150760e+13    1.150760e+13
# 4      1.897199e+13    1.897199e+13
# ..              ...             ...
# 296    1.150760e+13    3.303304e+15
# 297    1.897199e+13    3.303304e+15
# 298    2.830248e+13    3.303304e+15
# 299    2.830248e+13    0.000000e+00
# 300    3.949907e+13    0.000000e+00
#
# [301 rows x 257 columns]

# %%
time_slice_range = [0, 125]
df_slice = df[np.logical_and(
    df.time >= time_slice_range[0], 
    df.time <= time_slice_range[1]
)]
plt_figsize = (12, 6)

# %%
# STRESS V/S TIME
plt.figure(figsize=plt_figsize)
for r in range(land_size['rows']):
    for c in range(land_size['columns']):
        plt.plot(df_slice['time'], df_slice[f'p{r}{c}_stress'], label=f'p{r}{c}')
plt.xlabel("Year")
plt.ylabel("Stress")
plt.yscale("linear")
plt.title("Stress over Time")
plt.show()

# %%
# AGE RELATED STRESS V/S TIME
plt.figure(figsize=plt_figsize)
for r in range(land_size['rows']):
    for c in range(land_size['columns']):
        plt.plot(df_slice['time'], df_slice[f'p{r}{c}_stress_age'], label=f'p{r}{c}')
plt.xlabel("Year")
plt.ylabel("Age Stress")
plt.yscale("linear")
plt.title("Age Related Stress over Time")
plt.show()

# %%
# ENVIRONMENTAL STRESS V/S TIME
plt.figure(figsize=plt_figsize)
for r in range(land_size['rows']):
    for c in range(land_size['columns']):
        plt.plot(df_slice['time'], df_slice[f'p{r}{c}_stress_env'], label=f'p{r}{c}')
plt.xlabel("Year")
plt.ylabel("CO2 Stress")
plt.yscale("linear")
plt.title("Environmental Stress over Time")
plt.show()

# %%
# TREE SEPECIFIC C ABSORBED V/S TIME
plt.figure(figsize=plt_figsize)
for r in range(land_size['rows']):
    for c in range(land_size['columns']):
        plt.plot(df_slice['time'], df_slice[f'p{r}{c}_c_absorbed'], label=f'p{r}{c}')
plt.xlabel("Year")
plt.ylabel("CO2 (ppm)")
plt.yscale("linear")
plt.title("Tree Specific Carbon Absorbed over Time")
plt.show()

# %%
# TREE SEPECIFIC CO2 CONCENTRATION V/S TIME
plt.figure(figsize=plt_figsize)
for r in range(land_size['rows']):
    for c in range(land_size['columns']):
        plt.plot(df_slice['time'], df_slice[f'p{r}{c}_co2_ppm'], label=f'p{r}{c}')
plt.xlabel("Year")
plt.ylabel("CO2 (ppm)")
plt.yscale("linear")
plt.title("Tree Specific Atmospheric CO2 Concentration over Time")
plt.show()

# %%
# WORLD CO2 V/S TIME
plt.figure(figsize=plt_figsize)
plt.plot(df_slice['time'], df_slice['co2_ppm'])
plt.xlabel("Year")
plt.ylabel("CO2 (ppm)")
plt.yscale("linear")
plt.title("Atmospheric CO2 Concentration over Time")
plt.show()

# %%
# TREE LIFE STAGE V/S TIME
plt.figure(figsize=plt_figsize)
for r in range(land_size['rows']):
    for c in range(land_size['columns']):
        plt.plot(df_slice['time'], df_slice[f'p{r}{c}_stage'], label=f'p{r}{c}')
plt.xlabel("Year")
plt.ylabel("Life Stage")
plt.yscale("linear")
plt.title("Tree Life Stage over Time")
plt.show()
